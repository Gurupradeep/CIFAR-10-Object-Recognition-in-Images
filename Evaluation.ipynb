# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pylab

# %%
resnet = pd.read_csv("Results/ResNet50_without_dropout_without_conv_without_pool_basemap32.csv")

# %%
resnet
# Out:
#     epoch       acc      loss            lr  val_acc  val_loss
# 0       0  0.408131  1.635986  1.000000e-03   0.4192  1.640235
# 1       1  0.556472  1.240068  1.000000e-03   0.5689  1.188344
# 2       2  0.645626  0.997266  1.000000e-03   0.6059  1.181285
# 3       3  0.703060  0.845248  1.000000e-03   0.6809  1.003683
# 4       4  0.742170  0.734876  1.000000e-03   0.7156  0.836653
# 5       5  0.772869  0.654869  1.000000e-03   0.6774  1.011903
# 6       6  0.793396  0.592657  1.000000e-03   0.7372  0.846899
# 7       7  0.812560  0.540628  1.000000e-03   0.7675  0.786487
# 8       8  0.827119  0.500079  1.000000e-03   0.7855  0.664445
# 9       9  0.838413  0.465444  1.000000e-03   0.8065  0.576569
# 10     10  0.850048  0.432495  1.000000e-03   0.7924  0.643681
# 11     11  0.860802  0.401018  1.000000e-03   0.8301  0.504650
# 12     12  0.867731  0.377405  1.000000e-03   0.8351  0.488669
# 13     13  0.877984  0.353112  1.000000e-03   0.8356  0.499134
# ...

# %%
plt.plot(resnet["epoch"],resnet["val_acc"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")

# %%
figure.savefig("Resnet.png")

# %%
plt.plot(resnet["epoch"],resnet["val_loss"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation loss")

# %%
figure.savefig("ResNet_loss")

# %%
WRN = pd.read_csv("Results/WRN_16-8-with_dropout.csv")

# %%
WRN
# Out:
#     epoch       acc      loss            lr  val_acc  val_loss
# 0       0  0.524568  1.313850  1.000000e-03   0.4658  1.885848
# 1       1  0.690684  0.876134  1.000000e-03   0.6499  1.058078
# 2       2  0.761475  0.685405  1.000000e-03   0.7117  0.881397
# 3       3  0.799463  0.576138  1.000000e-03   0.7570  0.760727
# 4       4  0.825997  0.507323  1.000000e-03   0.7731  0.716314
# 5       5  0.843700  0.450848  1.000000e-03   0.7694  0.691402
# 6       6  0.860081  0.403641  1.000000e-03   0.8163  0.566250
# 7       7  0.875260  0.363825  1.000000e-03   0.8335  0.507307
# 8       8  0.886575  0.329925  1.000000e-03   0.8630  0.385045
# 9       9  0.894345  0.301796  1.000000e-03   0.8506  0.455567
# 10     10  0.904177  0.278365  1.000000e-03   0.8545  0.455590
# 11     11  0.913269  0.252337  1.000000e-03   0.8591  0.433379
# 12     12  0.940163  0.171021  3.162280e-04   0.9096  0.269077
# 13     13  0.948334  0.147657  3.162280e-04   0.9153  0.262807
# ...

# %%
plt.plot(WRN["epoch"],WRN["val_acc"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")
plt.show()

# %%
figure.savefig("WRN.png")

# %%
plt.plot(WRN["epoch"],WRN["val_loss"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Loss")
plt.show()

# %%
figure.savefig("WRN_loss")

# %%
plt.plot(resnet["epoch"],resnet["val_acc"],'r-',WRN['epoch'],WRN['val_acc'])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")

# %%
figure.savefig("comparison")

# %%
plt.plot(resnet["epoch"],resnet["val_loss"],'r-',WRN['epoch'],WRN['val_loss'])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Loss")

# %%
figure.savefig("Loss_Comparison")

# %%
resnet2 = pd.read_csv("Results/ResNet50_without_dropout_without_conv_without_pool.csv")

# %%
resnet2
# Out:
#     epoch       acc      loss            lr  val_acc  val_loss
# 0       0  0.367778  1.736815  1.000000e-03   0.4313  1.621649
# 1       1  0.507930  1.354666  1.000000e-03   0.5579  1.228859
# 2       2  0.587252  1.152685  1.000000e-03   0.6012  1.173388
# 3       3  0.643944  1.004709  1.000000e-03   0.6043  1.192108
# 4       4  0.695170  0.870828  1.000000e-03   0.6898  0.944721
# 5       5  0.725609  0.784936  1.000000e-03   0.7228  0.799339
# 6       6  0.750561  0.710334  1.000000e-03   0.6980  0.942628
# 7       7  0.774111  0.651445  1.000000e-03   0.7709  0.678664
# 8       8  0.789270  0.602286  1.000000e-03   0.7382  0.767273
# 9       9  0.805030  0.559959  1.000000e-03   0.7396  0.786805
# 10     10  0.816946  0.525476  1.000000e-03   0.7868  0.625241
# 11     11  0.826498  0.496637  1.000000e-03   0.7894  0.624058
# 12     12  0.837512  0.467720  1.000000e-03   0.7839  0.661859
# 13     13  0.848066  0.437183  1.000000e-03   0.8008  0.588105
# ...

# %%
plt.plot(resnet2["epoch"],resnet2["val_acc"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")

# %%
figure.savefig("resnet2")

# %%
plt.plot(resnet2["epoch"],resnet2["val_loss"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Loss")

# %%
figure.savefig("resnet2_loss")

# %%
plt.plot(resnet["epoch"],resnet["val_acc"],'r-',resnet2['epoch'],resnet2['val_acc'])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.show()

# %%
figure.savefig("Resnet_basemap32vs16_accuracy")

# %%
plt.plot(resnet["epoch"],resnet["val_loss"],'r-',resnet2['epoch'],resnet2['val_loss'])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")

# %%
lfigure

# %%
pylab.plot(resnet['epoch'],resnet['val_acc'],label = 'ResNet')
pylab.plot(WRN['epoch'],WRN['val_acc'],label = 'WRN')
figure = pylab.legend(loc = 'upper right')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Accuracy")
pylab.savefig("ResNet_vs_WRN_val_acc")
pylab.show()

# %%
pylab.plot(resnet['epoch'],resnet['val_loss'],label = 'ResNet')
pylab.plot(WRN['epoch'],WRN['val_loss'],label = 'WRN')
figure = pylab.legend(loc = 'upper right')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
pylab.savefig("ResNet_vs_WRN_val_loss")
pylab.show()

# %%
pylab.plot(resnet['epoch'],resnet['val_loss'],label = 'ResNet_Basemap32')
pylab.plot(resnet2['epoch'],resnet2['val_loss'],label = 'ResNet_Basemap16')
figure = pylab.legend(loc = 'upper right')
pylab.savefig("ResNet_basmap32_vs_16_val_loss")
pylab.show()

# %%
pylab.plot(resnet['epoch'],resnet['val_acc'],label = 'R-BM32')
pylab.plot(resnet2['epoch'],resnet2['val_acc'],label = 'R-BM16')
figure = pylab.legend(loc = 'upper right')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Accuracy")
pylab.savefig("ResNet_basmap32_vs_16_val_acc")
pylab.show()

# %%
WRN2 = pd.read_csv("Results/WRN_16-8-without_dropout.csv")

# %%
WRN2
# Out:
#     epoch       acc      loss        lr  val_acc  val_loss
# 0       0  0.518886  1.330050  0.001000   0.5580  1.279791
# 1       1  0.685718  0.891663  0.001000   0.6691  0.964039
# 2       2  0.754346  0.701922  0.001000   0.6712  1.065284
# 3       3  0.803168  0.574350  0.001000   0.7520  0.733164
# 4       4  0.831164  0.487628  0.001000   0.8163  0.550438
# 5       5  0.852131  0.431187  0.001000   0.8107  0.565627
# 6       6  0.870054  0.378490  0.001000   0.8029  0.589544
# 7       7  0.882670  0.342085  0.001000   0.7837  0.646404
# 8       8  0.921500  0.228787  0.000316   0.8927  0.311762
# 9       9  0.931272  0.200492  0.000316   0.8934  0.324384
# 10     10  0.936479  0.184987  0.000316   0.8931  0.331688
# 11     11  0.944329  0.163048  0.000316   0.8902  0.359771
# 12     12  0.957906  0.122611  0.000100   0.9159  0.255709
# 13     13  0.963413  0.107800  0.000100   0.9158  0.256280
# 14     14  0.966057  0.100279  0.000100   0.9159  0.263670
# ...

# %%
pylab.plot(WRN['epoch'],WRN['val_acc'],label = 'WRN-dropout')
pylab.plot(WRN2['epoch'],WRN2['val_acc'],label = 'WRN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Accuracy")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("WRN-With_and_without_dropout_val_acc")
pylab.show()

# %%
pylab.plot(WRN['epoch'],WRN['val_loss'],label = 'WRN-dropout')
pylab.plot(WRN2['epoch'],WRN2['val_loss'],label = 'WRN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("WRN-With_and_without_dropout_val_loss")
pylab.show()

# %%
simplecnn = pd.read_csv("Results/SimpleCNN_results.csv")

# %%
simplecnn
# Out:
#     epoch       acc      loss            lr  val_acc  val_loss
# 0       0  0.428097  1.900574  1.000000e-03   0.5606  1.288526
# 1       1  0.553268  1.499652  1.000000e-03   0.6501  1.192698
# 2       2  0.631628  1.247160  1.000000e-03   0.6712  1.219315
# 3       3  0.661507  1.146009  1.000000e-03   0.7053  0.955501
# 4       4  0.685798  1.066759  1.000000e-03   0.7261  0.878394
# 5       5  0.716257  0.915044  1.000000e-03   0.7614  0.784090
# 6       6  0.744713  0.819049  1.000000e-03   0.7811  0.722206
# 7       7  0.758331  0.785266  1.000000e-03   0.7958  0.697777
# 8       8  0.770426  0.759932  1.000000e-03   0.7989  0.688376
# 9       9  0.781060  0.736625  1.000000e-03   0.8053  0.670654
# 10     10  0.788690  0.719270  1.000000e-03   0.8100  0.661884
# 11     11  0.797941  0.701568  1.000000e-03   0.8126  0.654051
# 12     12  0.802968  0.687342  1.000000e-03   0.8195  0.645804
# 13     13  0.809216  0.674824  1.000000e-03   0.8242  0.640875
# ...

# %%
plt.plot(simplecnn["epoch"],simplecnn["val_acc"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")

# %%
figure.savefig("simplecnn_acc.png")

# %%
plt.plot(simplecnn["epoch"],simplecnn["val_loss"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation Accuracy")

# %%
figure.savefig("simplecnn_val_loss.png")

# %%
pylab.plot(WRN['epoch'],WRN['val_loss'],label = 'WRN-dropout')
pylab.plot(simplecnn['epoch'],simplecnn['val_loss'],label = 'SimpleCNN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("WRN_and_SimpleCNN_val_loss")
pylab.show()

# %%
pylab.plot(WRN['epoch'],WRN['val_acc'],label = 'WRN')
pylab.plot(simplecnn['epoch'],simplecnn['val_acc'],label = 'S-CNN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("WRN_and_SimpleCNN_val_acc")
pylab.show()

# %%
pylab.plot(resnet['epoch'],resnet['val_acc'],label = 'ResNet')
pylab.plot(simplecnn['epoch'],simplecnn['val_acc'],label = 'S-CNN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("ResNet_and_SimpleCNN_val_acc")
pylab.show()

# %%
pylab.plot(resnet['epoch'],resnet['val_loss'],label = 'ResNet')
pylab.plot(simplecnn['epoch'],simplecnn['val_loss'],label = 'S-CNN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("ResNet_and_SimpleCNN_val_loss")
pylab.show()

# %%
vgg = pd.read_csv("Results/vgg16imagenetpretrained_upsampleimage_cifar10_data_argumentation.csv")

# %%
vgg
# Out:
#     epoch       acc      loss            lr  val_acc  val_loss
# 0       0  0.339629  1.693363  1.000000e-03   0.3817  1.550955
# 1       1  0.434316  1.443026  1.000000e-03   0.4665  1.401919
# 2       2  0.524051  1.254391  1.000000e-03   0.5672  1.173143
# 3       3  0.603312  1.091959  1.000000e-03   0.6367  1.033902
# 4       4  0.642663  0.994602  1.000000e-03   0.6775  0.911932
# 5       5  0.671479  0.931370  1.000000e-03   0.6732  0.942200
# 6       6  0.693868  0.869848  1.000000e-03   0.7209  0.804449
# 7       7  0.707806  0.838481  1.000000e-03   0.7155  0.834796
# 8       8  0.720702  0.804591  1.000000e-03   0.7378  0.754999
# 9       9  0.731096  0.784383  1.000000e-03   0.7368  0.767846
# 10     10  0.743372  0.753940  1.000000e-03   0.7359  0.773621
# 11     11  0.749700  0.743873  1.000000e-03   0.7583  0.732452
# 12     12  0.756849  0.716355  1.000000e-03   0.7509  0.733586
# 13     13  0.762776  0.698444  1.000000e-03   0.7529  0.759714
# ...

# %%
plt.plot(vgg["epoch"],vgg["val_loss"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation loss")

# %%
figure.savefig("vgg_loss.png")

# %%
plt.plot(vgg["epoch"],vgg["val_acc"])
figure = plt.gcf()
plt.xlabel("No of Epochs")
plt.ylabel("Validation loss")

# %%
figure.savefig("vgg_Accuracy.png")

# %%
pylab.plot(vgg['epoch'],vgg['val_loss'],label = 'VGG')
pylab.plot(simplecnn['epoch'],simplecnn['val_loss'],label = 'SimpleCNN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("VGG_and_SimpleCNN_val_loss")
pylab.show()

# %%
pylab.plot(vgg['epoch'],vgg['val_acc'],label = 'VGG')
pylab.plot(simplecnn['epoch'],simplecnn['val_acc'],label = 'S-CNN')
pylab.xlabel("No of Epochs")
pylab.ylabel("Validation Loss")
figure = pylab.legend(loc = 'upper right')
pylab.savefig("VGG_and_SimpleCNN_val_acc")
pylab.show()
